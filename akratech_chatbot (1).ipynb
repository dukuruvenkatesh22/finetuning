# %%
pip install transformers accelerate bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 82.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 66.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 59.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
pip install peft

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "Dukuru/lora_model"  # Replace with full HF path

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",         # Uses GPU if available
    torch_dtype="auto"         # Efficient inference
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/55.4k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/876 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.49k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.35G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/97.3M [00:00<?, ?B/s]

# %%
def chat(user_input, history=[]):
    # Build the full conversation
    conversation = ""
    for i, (user, bot) in enumerate(history):
        conversation += f"User: {user}\nAssistant: {bot}\n"
    conversation += f"User: {user_input}\nAssistant:"

    inputs = tokenizer(conversation, return_tensors="pt").to(model.device)
    output = model.generate(
        **inputs,
        max_new_tokens=200,
        temperature=0.7,
        top_p=0.9,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id
    )

    response = tokenizer.decode(output[0], skip_special_tokens=True)
    response = response.split("Assistant:")[-1].strip()
    return response

# %%
history = []
while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit"]:
        break
    response = chat(user_input, history)
    history.append((user_input, response))
    print("Assistant:", response)
# Out:
# You: what is akratech
# Assistant: Akratech offers services like MVP development, Agile certification, and scalable PHP frameworks. They have certified professionals skilled in PHP, Python, and MERN stacks. Speak with an expert to know more.
# You: what are the services provided by akratech
# Assistant: You can speak with an expert by clicking the "Speak with an Expert" button on the Akratech website or by sending a message to their live chat support team. They are available 24/7 to assist you.
# You: who are you
# Assistant: You can speak with an expert by clicking the "Speak with an Expert" button on the Akratech website or by sending a message to their live chat support team. They are available 24/7 to assist you.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-785182140fb3> in <cell line: 0>()
#       1 history = []
#       2 while True:
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "Dukuru/lora_model"  # Your model on Hugging Face

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto")

# Define your question
question = "What tools does Akratech use for data visualization? (variation 5)"

# Tokenize input
inputs = tokenizer(question, return_tensors="pt").to(model.device)

# Generate response
outputs = model.generate(
    **inputs,
    max_new_tokens=200,
    temperature=0.7,
    top_p=0.9,
    do_sample=True,
    pad_token_id=tokenizer.eos_token_id
)

# Decode and print response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# What tools does Akratech use for data visualization? (variation 5) Akratech uses tools like Tableau, Power BI, and custom dashboards to provide actionable visual insights and facilitate strategic decision-making.
# Akratech offers services like predictive modeling, data mining, and statistical analysis to uncover hidden patterns and trends in data.
# Akratech certified professionals use tools like R, Python, and SQL to develop predictive models and actionable statistical insights.
# Akratech implements machine learning algorithms and statistical models to provide predictive forecasting and real-time analytics dashboards.
